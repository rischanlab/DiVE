# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
input_file = "IO_cost_lambda.csv"
output_plot = "IO_cost_lambda.svg"

column_names = ['tradeoff','Only Importance','i-DiVE-Greedy-Adaptive-Pruning','i-DiVE-SwapD-Adaptive-Pruning']
df = pd.read_csv(input_file, header=None, names = column_names)

df = df.set_index(['tradeoff'])
df = df[['i-DiVE-SwapD-Adaptive-Pruning','i-DiVE-Greedy-Adaptive-Pruning','Only Importance']]

markers = ['o','+','*','*']
linestyles = ['-.','-','--','--']


#my_color = ['orange', 'magenta', 'maroon', 'red']

my_color = ['black', 'black', 'black', 'black', 'black', 'black']


ax = df.plot(kind='line', markersize=7, linewidth=1,color=my_color)
for i, line in enumerate(ax.get_lines()):
    line.set_marker(markers[i])

for i, line in enumerate(ax.get_lines()):
    line.set_linestyle(linestyles[i])

# for adding legend
ax.legend(ax.get_lines(), df.columns, loc='best')

# Set the formatter
plt.xlabel(r'$\lambda$', fontsize=10)
plt.ylabel('I/O cost normalized to Only Importance', fontsize=10)
plt.autolayout : True
ax.set_ylim(ymax=1.1)
ax.set_ylim(ymin=0)
plt.savefig(output_plot, format="svg", dpi = 1000, bbox_inches='tight')
plt.show()

# %%
input_file = "CPU_cost_lambda.csv"
output_plot = "CPU_cost_lambda.svg"

column_names = ['tradeoff','Only Importance','i-DiVE-Greedy-Adaptive-Pruning','i-DiVE-SwapD-Adaptive-Pruning']
df = pd.read_csv(input_file, header=None, names = column_names)

df = df.set_index(['tradeoff'])
df = df[['i-DiVE-SwapD-Adaptive-Pruning','i-DiVE-Greedy-Adaptive-Pruning','Only Importance']]

markers = ['o','+','*','*']
linestyles = ['-.','-','--','--']


#my_color = ['orange', 'magenta', 'maroon', 'red']

my_color = ['black', 'black', 'black', 'black', 'black', 'black']


ax = df.plot(kind='line', markersize=7, linewidth=1,color=my_color)
for i, line in enumerate(ax.get_lines()):
    line.set_marker(markers[i])

for i, line in enumerate(ax.get_lines()):
    line.set_linestyle(linestyles[i])

# for adding legend
ax.legend(ax.get_lines(), df.columns, loc='best')

# Set the formatter
plt.xlabel(r'$\lambda$', fontsize=10)
plt.ylabel('CPU cost normalized to Only Importance', fontsize=10)
plt.autolayout : True
ax.set_ylim(ymax=1.1)
ax.set_ylim(ymin=0)
plt.savefig(output_plot, format="svg", dpi = 1000, bbox_inches='tight')
plt.show()
